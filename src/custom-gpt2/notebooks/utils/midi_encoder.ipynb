# %% [markdown]
# # MIDI encoder example
#
# The chunk of code bellow illustrates how to use the MIDI Encoder from the [make_token_sequence_dataset](../../src/data/make_token_sequence_dataset.py) module to encode MIDI to text

# %%
# Imports python modules located at the src/data directory (make_token_sequence_dataset)
import sys
sys.path.append('../..')

import note_seq
from make_token_sequence_dataset import extract_tokens_from_note_sequence


PRIMER_EXTRACT = 'prelude_in_c_major.mid'
PRIMER_PATH = f'../../resources/midi/{PRIMER_EXTRACT}'
AUGMENTATION_OUTPUT_PATH = 'augmentation_example'
notes = note_seq.midi_file_to_note_sequence(PRIMER_PATH)

# %% [markdown]
# # Play and plot of MIDI extract

# %%
note_seq.play_sequence(notes)
note_seq.plot_sequence(notes)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1161">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="90d72fe6-3f60-4fe8-ad83-e70dc82ffbc4" data-root-id="1112"></div>

# %%
extract_tokens_from_note_sequence(notes)
# Out:
# 'piece_start velocity=12 note_on=60 note_off=60 note_on=64 note_off=64 velocity=15 note_on=67 note_off=67 note_on=72 note_off=72 velocity=16 note_on=76 note_off=76 velocity=15 note_on=67 note_off=67 note_on=72 note_off=72 note_on=76 note_off=76 note_on=60 note_off=60 note_on=64 note_off=64 note_on=67 note_off=67 velocity=16 note_on=72 note_off=72 velocity=15 note_on=76 note_off=76 velocity=16 note_on=67 note_off=67 velocity=17 note_on=72 note_off=72 velocity=16 note_on=76 note_off=76 piece_end'
